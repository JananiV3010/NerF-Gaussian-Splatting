# %%
# !pip install nerfstudio[full] --upgrade
# !sudo apt-get update
# !sudo apt-get install -y ffmpeg
# Out:
# ...
# WARNING: nerfstudio 1.1.5 does not provide the extra 'full'
# ...
# Hit:1 https://cli.github.com/packages stable InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:4 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:6 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:7 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# ...

# %%
# !ns-process-data --help
# Out:
# usage: /usr/local/bin/ns-process-data [-h] {images,video,polycam,metashape,realitycapture,record3d,odm,aria}
#
# ╭─ options ────────────────────────────────────────────────────────────────────╮
# │ -h, --help          show this help message and exit                          │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ subcommands ────────────────────────────────────────────────────────────────╮
# │ (required)                                                                   │
# │   • images          Process images into a nerfstudio dataset.                │
# │                     1. Scales images to a specified size.                    │
# │                     2. Calculates the camera poses for each image using      │
# │                     `COLMAP <https://colmap.github.io/>`_.                   │
# │   • video           Process videos into a nerfstudio dataset. This script    │
# ...

# %%
from google.colab import files
uploaded = files.upload()  # pick your 1:55 video, e.g., books.mp4
# Out:
#      <input type="file" id="files-fa742eb2-74fd-4eb6-9a7b-67fb7e699df8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fa742eb2-74fd-4eb6-9a7b-67fb7e699df8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !ns-process-data video \
  --data books.mp4 \
  --output-dir data/books_processed \
  --num-frames-target 200 \
  --run-colmap
# Out:
# ╭─ Unrecognized options ───────────────────────────────────────╮
# │ Unrecognized options: --run-colmap                           │
# │ ──────────────────────────────────────────────────────────── │
# │ For full helptext, run /usr/local/bin/ns-process-data --help │
# ╰──────────────────────────────────────────────────────────────╯

# %%
mkdir -p data/books_raw
# 2 fps → about 230 frames from ~115 s
# !ffmpeg -i books.mp4 -vf fps=2 -q:v 2 data/books_raw/frame_%05d.jpg

# %%
mkdir -p data/books
# !mogrify -path data/books -resize 800x800\> data/books_raw/*.jpg
